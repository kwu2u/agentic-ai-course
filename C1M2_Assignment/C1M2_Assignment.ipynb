# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
You are an expert academic writer with a PhD-level understanding of scholarly communication. Your task is to write a comprehensive, well-structured essay.

## ESSAY REQUIREMENTS:
- Produce a COMPLETE, POLISHED, and PUBLICATION-READY essay in Markdown format
- Develop a cohesive narrative with critical analysis
- Length should be appropriate to thoroughly cover the topic (typically 1500-3000 words)

## MANDATORY STRUCTURE:
1. **Title**: Clear, concise, and descriptive of the content
2. **Introduction**: Present the topic, question/problem, significance, and outline of the essay
3. **Background/Literature Review**: Contextualize the topic within existing scholarship
4. **Key Thesis**: Present the primary thesis and evidence for it
5. **Discussion**: Interpret findings, address implications, limitations, and connections to broader field
6. **Conclusion**: Synthesize main points and suggest directions for future research

## ACADEMIC WRITING GUIDELINES:
- Maintain formal, precise, and objective language throughout
- Use discipline-appropriate terminology and concepts
- Support all claims with evidence and reasoning
- Develop logical flow between ideas, paragraphs, and sections
- Include relevant examples, case studies, data, or equations to strengthen arguments
- Address potential counterarguments and limitations

## FORMATTING GUIDELINES:
- Use Markdown syntax for all formatting (headings, emphasis, lists, etc.)
- Include appropriate section headings and subheadings to organize content
- Format any equations, tables, or figures according to academic conventions
- Use bullet points or numbered lists when appropriate for clarity

Output the complete report in Markdown format only. Do not include meta-commentary about the writing process.

INTERNAL CHECKLIST (DO NOT INCLUDE IN OUTPUT):
- [ ] Developed original analysis beyond mere summarization
- [ ] Included all mandatory sections with appropriate content
- [ ] Maintained academic tone and language throughout
- [ ] Ensured logical flow and coherent structure

USER TOPIC REQUEST:
{topic}
    """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
You are a professional academic editor with expertise in improving scholarly writing across disciplines. Your task is to refine and elevate the quality of the essay provided.

## Your Editing Process:
1. Analyze the overall structure, argument flow, and coherence of the text
2. Ensure logical progression of ideas with clear topic sentences and transitions between paragraphs
3. Improve clarity, precision, and conciseness of language while maintaining academic tone
4. Verify technical accuracy (to the extent possible based on context)
5. Enhance readability through appropriate formatting and organization

## Specific Elements to Address:
- Strengthen thesis statements and main arguments
- Clarify complex concepts with additional explanations or examples where needed
- Add relevant equations, diagrams, or illustrations (described in markdown) when they would enhance understanding
- Ensure proper integration of evidence and maintain academic rigor
- Standardize terminology and eliminate redundancies
- Improve sentence variety and paragraph structure

## Formatting Guidelines:
- Use markdown formatting consistently for headings, emphasis, lists, etc.
- Structure content with appropriate section headings and subheadings
- Format equations, tables, and figures according to academic standards

Essay:
{draft}

Return explanatory comments and suggested edits.
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
You are an expert academic writer with a PhD-level understanding of scholarly communication.
Your task is to revise the original text with the provided feedback from you editor.

## ACADEMIC WRITING GUIDELINES:
- Maintain formal, precise, and objective language throughout
- Use discipline-appropriate terminology and concepts
- Support all claims with evidence and reasoning
- Develop logical flow between ideas, paragraphs, and sections
- Include relevant examples, case studies, data, or equations to strengthen arguments
- Address potential counterarguments and limitations

## FORMATTING GUIDELINES:
- Use Markdown syntax for all formatting (headings, emphasis, lists, etc.)
- Include appropriate section headings and subheadings to organize content
- Format any equations, tables, or figures according to academic conventions
- Use bullet points or numbered lists when appropriate for clarity

Original essay (for context):
{original_draft}

Feedback from editor:
{reflection}

Return only the revised, polished text in Markdown format without explanatory comments about your edits.
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# # Should Social Media Platforms Be Regulated by the Government?
#
# ## Introduction
#
# The exponential rise of social media platforms over the past two decades has instigated an extensive debate concerning their regulation. These digital forums, which now serve billions of users worldwide, have revolutionized communication, enabling unprecedented connectivity and democratization of information. However, the unfettered reach and influence of platforms such as Facebook, Twitter, and Instagram have also precipitated significant ethical, social, and political challenges. These include issues of privacy infringement, misinformation, and the potential for manipulating democratic processes.
#
# The central question this essay addresses is whether government regulation of social media platforms is both viable and necessary in the contemporary digital landscape. The significance of this inquiry lies in the intersection of technological advancement, individual rights, and collective societal values. This essay will outline the current regulatory landscape, evaluate arguments for and against governmental intervention, and explore potential frameworks for regulation that balance the myriad interests at stake.
#
# ## Background/Literature Review
#
# The discourse surrounding social media regulation is situated within broader debates on digital governance and internet freedoms. In the burgeoning scholarship, scholars such as Gillespie (2018) and van Dijck (2013) emphasize the unprecedented power of social media corporations, which, as private entities, operate primarily under market logics that may conflict with public interests. Existing regulatory frameworks are largely national in scope, varying significantly between democratic, authoritarian, and developing contexts (MacKinnon, 2012).
#
# Key legislative efforts, such as the European Union's General Data Protection Regulation (GDPR), represent landmark efforts in digital regulation, aiming to provide robust protections for personal data and privacy. In contrast, the regulatory approaches in the United States have historically leaned towards self-regulation by tech firms, reflecting a deep-rooted ethos of free expression and market autonomy (Klonick, 2018).
#
# However, recent developments, including the Cambridge Analytica scandal and the role of social media in electoral interference, have intensified calls for reevaluating this laissez-faire stance. The literature further explores critical issues such as algorithmic transparency, content moderation, and the ethical responsibilities of platform providers (Pasquale, 2015).
#
# ## Key Thesis
#
# This essay posits that while government regulation of social media platforms is necessary to safeguard democratic processes and individual rights, such regulation must be carefully crafted to avoid stifling innovation or infringing on free speech. Evidence from jurisdictions with existing regulations demonstrates the potential for balancing these priorities, though significant challenges remain.
#
# ## Discussion
#
# ### The Case for Government Regulation
#
# Proponents of government regulation argue that unchecked power held by social media conglomerates poses threats to both individual privacy and societal welfare. For instance, Sonnemaker (2020) highlights the capacity for these companies to collect vast amounts of personal data, often without explicit consent, leading to concerns over surveillance capitalism (Zuboff, 2019). Regulating data collection and usage is imperative to protect user privacy and prevent abuse.
#
# Moreover, social media's role in disseminating misinformation and polarizing public discourse underscores the need for accountability. As Wardle and Derakhshan (2017) illustrate, false information can spread rapidly, influencing public opinion and potentially inciting real-world harm. Government intervention could ensure stringent content moderation and fact-checking practices, fostering a more informed citizenry.
#
# ### Counterarguments Against Regulation
#
# Critics of government intervention warn of the risks associated with curtailing the free flow of information. As Lessig (2006) argues, overregulation could stifle the inherent creativity and innovation that digital platforms inspire. Furthermore, concerns over governmental overreach and censorship are particularly pronounced in authoritarian regimes, where regulation can serve as a guise for political repression (Deibert, 2018).
#
# Additionally, the dynamic, transnational nature of social media poses significant challenges to regulatory implementation and enforcement. The global digital ecosystem requires coordinated, cross-border regulatory efforts, which are often difficult to achieve due to divergent legal and cultural norms (Floridi, 2014).
#
# ### Potential Regulatory Frameworks
#
# To address these complex challenges, multi-stakeholder governance models have gained traction, advocating for collaboration between governments, industry leaders, and civil society. One such model is the Digital Services Act proposed by the European Commission, which seeks to enhance platform accountability while maintaining user rights and innovation incentives.
#
# Another approach involves enhancing algorithmic accountability through transparency mandates. By requiring platforms to disclose the criteria used in content curation and recommendation, policymakers can mitigate bias and manipulation risks while preserving platform autonomy (Tufekci, 2018).
#
# ## Conclusion
#
# In synthesizing the arguments and evidence, it becomes clear that government regulation of social media platforms is both a pressing necessity and a complex endeavor. While regulation presents risks of stifling innovation and free expression, strategic, transparent policies that involve a broad range of stakeholders can mitigate these concerns. Future research should focus on developing holistic frameworks that reconcile technological progress with ethical considerations, prioritizing user protection and public welfare without compromising the vibrant exchange of ideas that defines the digital age. As social media continues to evolve, so too must the strategies for governing this critical facet of modern life, ensuring it serves the collective good.
#
# 🧠 Feedback:
#
# Below is a thoroughly revised version of your essay, followed by explanatory comments and suggestions. I’ve strengthened the thesis, improved flow and clarity, added illustrative tables/diagrams (in markdown), and standardized terminology.
#
# ---
#
# # Should Social Media Platforms Be Regulated by the Government?
#
# ## 1. Introduction
# The exponential rise of social media platforms over the past two decades has revolutionized communication, enabling unprecedented connectivity and democratization of information. At the same time, platforms such as Facebook, Twitter, and Instagram have given rise to serious ethical, social, and political challenges—most notably privacy infringements, the rapid spread of misinformation, and the manipulation of democratic processes.
#
# **Thesis (revised):**
# While government regulation of social media is necessary to safeguard democratic norms and individual rights, such regulation must be narrowly tailored—enhancing transparency, protecting privacy, and ensuring accountability—without stifling innovation or infringing on free expression.
#
# ## 2. Background and Literature Review
#
# ### 2.1 Digital Governance and Platform Power
# Scholars like Gillespie (2018) and van Dijck (2013) emphasize how major platforms operate under market logics that may conflict with public interests. As private entities, they set content-moderation rules, design proprietary algorithms, and monetize user data.
#
# ### 2.2 National Approaches to Regulation
# - **European Union (GDPR):** Establishes robust data-protection rights and penalties for non-compliance (MacCarthy, 2020).
# - **United States:** Relies largely on self-regulation, grounded in free-speech traditions (Klonick, 2018).
# - **Emerging Economies:** Face resource constraints and often adopt ad hoc measures, risking both under- and over-regulation (MacKinnon, 2012).
#
# ### 2.3 Recent Catalysts for Reform
# The Cambridge Analytica scandal (2018) and documented cases of electoral interference have intensified calls for more stringent oversight (Wardle & Derakhshan, 2017; Zuboff, 2019).
#
# ## 3. The Case for Government Regulation
#
# ### 3.1 Privacy and Surveillance Capitalism
# Platforms amass detailed profiles of users—often without explicit, informed consent—fueling “surveillance capitalism” (Zuboff, 2019). Regulation can:
# - Mandate clear, granular consent mechanisms
# - Limit data retention periods
# - Impose penalties for unauthorized secondary data use
#
# ### 3.2 Misinformation and Public Harm
# False or misleading content can spread exponentially, shaping public opinion and causing real-world harm (Wardle & Derakhshan, 2017). Government-mandated transparency in content-moderation policies and independent fact-checking bodies could mitigate these risks.
#
# ## 4. Counterarguments
#
# ### 4.1 Innovation and Free Expression
# Lessig (2006) warns that heavy-handed rules may deter startups and chill legitimate speech. Any regulatory regime must preserve:
# - Low barriers to entry for new platforms
# - Protections for political and artistic expression
#
# ### 4.2 Risks of Government Overreach
# Authoritarian regimes may exploit regulation to suppress dissent (Deibert, 2018). Furthermore, the cross-border nature of social media calls for international coordination—often impeded by divergent legal and cultural norms (Floridi, 2014).
#
# ## 5. Potential Regulatory Frameworks
#
# ### 5.1 Multi-Stakeholder Governance
# Collaborative models bring together governments, tech firms, civil society, and academia.
# ```markdown
# Figure 1: Multi-Stakeholder Governance Model
# - Government: Sets baseline rules and enforcement
# - Platforms: Implement and report on compliance
# - Civil society: Monitors impact and raises public concerns
# - Academia/Experts: Evaluate algorithms and advise on best practices
# ```
#
# ### 5.2 Algorithmic Accountability
# Mandating “algorithmic impact assessments” would require platforms to audit recommendation systems for bias and manipulation.
#
# | Framework                      | Scope                     | Advantages                         | Challenges                              |
# |--------------------------------|---------------------------|------------------------------------|-----------------------------------------|
# | EU Digital Services Act (DSA)  | Civil liability & rights  | Strong consumer protections        | Implementation across non-EU platforms  |
# | Algorithmic Impact Assessments | Algorithmic transparency  | Mitigates hidden biases            | Proprietary concerns & technical costs  |
#
# ## 6. Conclusion
# Government regulation of social media is both urgent and feasible—but only if it balances three core objectives: (1) protecting individual rights (privacy, expression), (2) safeguarding democratic processes (preventing misinformation and manipulation), and (3) fostering innovation (low entry barriers, algorithmic R&D). Future research should develop interoperable, international standards and explore adaptive regulatory “sandboxes” that allow for iterative policy testing. By combining clear legal mandates with multi-stakeholder oversight, we can ensure that social media continues to serve the public good.
#
# ---
#
# # Explanatory Comments and Suggestions
#
# 1. **Strengthened Thesis (Section 1):**
#    – Moved thesis to end of introduction and made it more specific (balance of rights, transparency, innovation).
# 2. **Clearer Literature Review (Section 2):**
#    – Split into subheadings for digital governance, national approaches, and catalysts for reform.
#    – Added recent citations to illustrate evolving debates.
# 3. **Improved Argument Flow (Sections 3–4):**
#    – Organized pros and cons into parallel subsections (3.1/3.2 vs. 4.1/4.2) for symmetry and clearer comparison.
# 4. **Added Illustrations (Section 5):**
#    – Included a diagram (described in markdown) for the multi-stakeholder model.
#    – Provided a comparative table of regulation frameworks to visualize trade-offs.
# 5. **Enhanced Transitions:**
#    – Each section now begins with a brief topic sentence and ends with a transition statement.
# 6. **Terminology and Style:**
#    – Standardized terms (e.g., “algorithmic accountability,” “surveillance capitalism”).
#    – Varied sentence structure and reduced nominalizations for readability.
# 7. **Future Research (Conclusion):**
#    – Suggested specific directions (interoperable standards, regulatory sandboxes) to underscore academic rigor and forward momentum.
#
# Please let me know if you’d like further detail on any point or additional diagrams/equations to illustrate specific concepts.
# ✍️ Revised:
#
# ```markdown
# # Should Social Media Platforms Be Regulated by the Government?
#
# ## 1. Introduction
# The exponential rise of social media platforms over the past two decades has revolutionized communication, enabling unprecedented connectivity and democratization of information. At the same time, platforms such as Facebook, Twitter, and Instagram have given rise to serious ethical, social, and political challenges—most notably privacy infringements, the rapid spread of misinformation, and the manipulation of democratic processes.
#
# **Thesis (revised):**
# While government regulation of social media is necessary to safeguard democratic norms and individual rights, such regulation must be narrowly tailored—enhancing transparency, protecting privacy, and ensuring accountability—without stifling innovation or infringing on free expression.
#
# ## 2. Background and Literature Review
#
# ### 2.1 Digital Governance and Platform Power
# Scholars like Gillespie (2018) and van Dijck (2013) emphasize how major platforms operate under market logics that may conflict with public interests. As private entities, they set content-moderation rules, design proprietary algorithms, and monetize user data.
#
# ### 2.2 National Approaches to Regulation
# - **European Union (GDPR):** Establishes robust data-protection rights and penalties for non-compliance (MacCarthy, 2020).
# - **United States:** Relies largely on self-regulation, grounded in free-speech traditions (Klonick, 2018).
# - **Emerging Economies:** Face resource constraints and often adopt ad hoc measures, risking both under- and over-regulation (MacKinnon, 2012).
#
# ### 2.3 Recent Catalysts for Reform
# The Cambridge Analytica scandal (2018) and documented cases of electoral interference have intensified calls for more stringent oversight (Wardle & Derakhshan, 2017; Zuboff, 2019).
#
# ## 3. The Case for Government Regulation
#
# ### 3.1 Privacy and Surveillance Capitalism
# Platforms amass detailed profiles of users—often without explicit, informed consent—fueling “surveillance capitalism” (Zuboff, 2019). Regulation can:
# - Mandate clear, granular consent mechanisms
# - Limit data retention periods
# - Impose penalties for unauthorized secondary data use
#
# ### 3.2 Misinformation and Public Harm
# False or misleading content can spread exponentially, shaping public opinion and causing real-world harm (Wardle & Derakhshan, 2017). Government-mandated transparency in content-moderation policies and independent fact-checking bodies could mitigate these risks.
#
# ## 4. Counterarguments
#
# ### 4.1 Innovation and Free Expression
# Lessig (2006) warns that heavy-handed rules may deter startups and chill legitimate speech. Any regulatory regime must preserve:
# - Low barriers to entry for new platforms
# - Protections for political and artistic expression
#
# ### 4.2 Risks of Government Overreach
# Authoritarian regimes may exploit regulation to suppress dissent (Deibert, 2018). Furthermore, the cross-border nature of social media calls for international coordination—often impeded by divergent legal and cultural norms (Floridi, 2014).
#
# ## 5. Potential Regulatory Frameworks
#
# ### 5.1 Multi-Stakeholder Governance
# Collaborative models bring together governments, tech firms, civil society, and academia.
# ```markdown
# Figure 1: Multi-Stakeholder Governance Model
# - Government: Sets baseline rules and enforcement
# - Platforms: Implement and report on compliance
# - Civil society: Monitors impact and raises public concerns
# - Academia/Experts: Evaluate algorithms and advise on best practices
# ```
#
# ### 5.2 Algorithmic Accountability
# Mandating “algorithmic impact assessments” would require platforms to audit recommendation systems for bias and manipulation.
#
# | Framework                      | Scope                     | Advantages                         | Challenges                              |
# |--------------------------------|---------------------------|------------------------------------|-----------------------------------------|
# | EU Digital Services Act (DSA)  | Civil liability & rights  | Strong consumer protections        | Implementation across non-EU platforms  |
# | Algorithmic Impact Assessments | Algorithmic transparency  | Mitigates hidden biases            | Proprietary concerns & technical costs  |
#
# ## 6. Conclusion
# Government regulation of social media is both urgent and feasible—but only if it balances three core objectives: (1) protecting individual rights (privacy, expression), (2) safeguarding democratic processes (preventing misinformation and manipulation), and (3) fostering innovation (low entry barriers, algorithmic R&D). Future research should develop interoperable, international standards and explore adaptive regulatory “sandboxes” that allow for iterative policy testing. By combining clear legal mandates with multi-stakeholder oversight, we can ensure that social media continues to serve the public good.
# ```

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         "># Should Social Media Platforms Be Regulated by the Government?
#
# ## Introduction
#
# The exponential rise of social media platforms over the past two decades has instigated an extensive debate concerning their regulation. These digital forums, which now serve billions of users worldwide, have revolutionized communication, enabling unprecedented connectivity and democratization of information. However, the unfettered reach and influence of platforms such as Facebook, Twitter, and Instagram have also precipitated significant ethical, social, and political challenges. These include issues of privacy infringement, misinformation, and the potential for manipulating democratic processes.
#
# The central question this essay addresses is whether government regulation of social media platforms is both viable and necessary in the contemporary digital landscape. The significance of this inquiry lies in the intersection of technological advancement, individual rights, and collective societal values. This essay will outline the current regulatory landscape, evaluate arguments for and against governmental intervention, and explore potential frameworks for regulation that balance the myriad interests at stake.
#
# ## Background/Literature Review
#
# The discourse surrounding social media regulation is situated within broader debates on digital governance and internet freedoms. In the burgeoning scholarship, scholars such as Gillespie (2018) and van Dijck (2013) emphasize the unprecedented power of social media corporations, which, as private entities, operate primarily under market logics that may conflict with public interests. Existing regulatory frameworks are largely national in scope, varying significantly between democratic, authoritarian, and developing contexts (MacKinnon, 2012).
#
# Key legislative efforts, such as the European Union's General Data Protection Regulation (GDPR), represent landmark efforts in digital regulation, aiming to provide robust protections for personal data and privacy. In contrast, the regulatory approaches in the United States have historically leaned towards self-regulation by tech firms, reflecting a deep-rooted ethos of free expression and market autonomy (Klonick, 2018).
#
# However, recent developments, including the Cambridge Analytica scandal and the role of social media in electoral interference, have intensified calls for reevaluating this laissez-faire stance. The literature further explores critical issues such as algorithmic transparency, content moderation, and the ethical responsibilities of platform providers (Pasquale, 2015).
#
# ## Key Thesis
#
# This essay posits that while government regulation of social media platforms is necessary to safeguard democratic processes and individual rights, such regulation must be carefully crafted to avoid stifling innovation or infringing on free speech. Evidence from jurisdictions with existing regulations demonstrates the potential for balancing these priorities, though significant challenges remain.
#
# ## Discussion
#
# ### The Case for Government Regulation
#
# Proponents of government regulation argue that unchecked power held by social media conglomerates poses threats to both individual privacy and societal welfare. For instance, Sonnemaker (2020) highlights the capacity for these companies to collect vast amounts of personal data, often without explicit consent, leading to concerns over surveillance capitalism (Zuboff, 2019). Regulating data collection and usage is imperative to protect user privacy and prevent abuse.
#
# Moreover, social media's role in disseminating misinformation and polarizing public discourse underscores the need for accountability. As Wardle and Derakhshan (2017) illustrate, false information can spread rapidly, influencing public opinion and potentially inciting real-world harm. Government intervention could ensure stringent content moderation and fact-checking practices, fostering a more informed citizenry.
#
# ### Counterarguments Against Regulation
#
# Critics of government intervention warn of the risks associated with curtailing the free flow of information. As Lessig (2006) argues, overregulation could stifle the inherent creativity and innovation that digital platforms inspire. Furthermore, concerns over governmental overreach and censorship are particularly pronounced in authoritarian regimes, where regulation can serve as a guise for political repression (Deibert, 2018).
#
# Additionally, the dynamic, transnational nature of social media poses significant challenges to regulatory implementation and enforcement. The global digital ecosystem requires coordinated, cross-border regulatory efforts, which are often difficult to achieve due to divergent legal and cultural norms (Floridi, 2014).
#
# ### Potential Regulatory Frameworks
#
# To address these complex challenges, multi-stakeholder governance models have gained traction, advocating for collaboration between governments, industry leaders, and civil society. One such model is the Digital Services Act proposed by the European Commission, which seeks to enhance platform accountability while maintaining user rights and innovation incentives.
#
# Another approach involves enhancing algorithmic accountability through transparency mandates. By requiring platforms to disclose the criteria used in content curation and recommendation, policymakers can mitigate bias and manipulation risks while preserving platform autonomy (Tufekci, 2018).
#
# ## Conclusion
#
# In synthesizing the arguments and evidence, it becomes clear that government regulation of social media platforms is both a pressing necessity and a complex endeavor. While regulation presents risks of stifling innovation and free expression, strategic, transparent policies that involve a broad range of stakeholders can mitigate these concerns. Future research should focus on developing holistic frameworks that reconcile technological progress with ethical considerations, prioritizing user protection and public welfare without compromising the vibrant exchange of ideas that defines the digital age. As social media continues to evolve, so too must the strategies for governing this critical facet of modern life, ensuring it serves the collective good.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Below is a thoroughly revised version of your essay, followed by explanatory comments and suggestions. I’ve strengthened the thesis, improved flow and clarity, added illustrative tables/diagrams (in markdown), and standardized terminology.
#
# ---
#
# # Should Social Media Platforms Be Regulated by the Government?
#
# ## 1. Introduction
# The exponential rise of social media platforms over the past two decades has revolutionized communication, enabling unprecedented connectivity and democratization of information. At the same time, platforms such as Facebook, Twitter, and Instagram have given rise to serious ethical, social, and political challenges—most notably privacy infringements, the rapid spread of misinformation, and the manipulation of democratic processes.
#
# **Thesis (revised):**
# While government regulation of social media is necessary to safeguard democratic norms and individual rights, such regulation must be narrowly tailored—enhancing transparency, protecting privacy, and ensuring accountability—without stifling innovation or infringing on free expression.
#
# ## 2. Background and Literature Review
#
# ### 2.1 Digital Governance and Platform Power
# Scholars like Gillespie (2018) and van Dijck (2013) emphasize how major platforms operate under market logics that may conflict with public interests. As private entities, they set content-moderation rules, design proprietary algorithms, and monetize user data.
#
# ### 2.2 National Approaches to Regulation
# - **European Union (GDPR):** Establishes robust data-protection rights and penalties for non-compliance (MacCarthy, 2020).
# - **United States:** Relies largely on self-regulation, grounded in free-speech traditions (Klonick, 2018).
# - **Emerging Economies:** Face resource constraints and often adopt ad hoc measures, risking both under- and over-regulation (MacKinnon, 2012).
#
# ### 2.3 Recent Catalysts for Reform
# The Cambridge Analytica scandal (2018) and documented cases of electoral interference have intensified calls for more stringent oversight (Wardle & Derakhshan, 2017; Zuboff, 2019).
#
# ## 3. The Case for Government Regulation
#
# ### 3.1 Privacy and Surveillance Capitalism
# Platforms amass detailed profiles of users—often without explicit, informed consent—fueling “surveillance capitalism” (Zuboff, 2019). Regulation can:
# - Mandate clear, granular consent mechanisms
# - Limit data retention periods
# - Impose penalties for unauthorized secondary data use
#
# ### 3.2 Misinformation and Public Harm
# False or misleading content can spread exponentially, shaping public opinion and causing real-world harm (Wardle & Derakhshan, 2017). Government-mandated transparency in content-moderation policies and independent fact-checking bodies could mitigate these risks.
#
# ## 4. Counterarguments
#
# ### 4.1 Innovation and Free Expression
# Lessig (2006) warns that heavy-handed rules may deter startups and chill legitimate speech. Any regulatory regime must preserve:
# - Low barriers to entry for new platforms
# - Protections for political and artistic expression
#
# ### 4.2 Risks of Government Overreach
# Authoritarian regimes may exploit regulation to suppress dissent (Deibert, 2018). Furthermore, the cross-border nature of social media calls for international coordination—often impeded by divergent legal and cultural norms (Floridi, 2014).
#
# ## 5. Potential Regulatory Frameworks
#
# ### 5.1 Multi-Stakeholder Governance
# Collaborative models bring together governments, tech firms, civil society, and academia.
# ```markdown
# Figure 1: Multi-Stakeholder Governance Model
# - Government: Sets baseline rules and enforcement
# - Platforms: Implement and report on compliance
# - Civil society: Monitors impact and raises public concerns
# - Academia/Experts: Evaluate algorithms and advise on best practices
# ```
#
# ### 5.2 Algorithmic Accountability
# Mandating “algorithmic impact assessments” would require platforms to audit recommendation systems for bias and manipulation.
#
# | Framework                      | Scope                     | Advantages                         | Challenges                              |
# |--------------------------------|---------------------------|------------------------------------|-----------------------------------------|
# | EU Digital Services Act (DSA)  | Civil liability & rights  | Strong consumer protections        | Implementation across non-EU platforms  |
# | Algorithmic Impact Assessments | Algorithmic transparency  | Mitigates hidden biases            | Proprietary concerns & technical costs  |
#
# ## 6. Conclusion
# Government regulation of social media is both urgent and feasible—but only if it balances three core objectives: (1) protecting individual rights (privacy, expression), (2) safeguarding democratic processes (preventing misinformation and manipulation), and (3) fostering innovation (low entry barriers, algorithmic R&D). Future research should develop interoperable, international standards and explore adaptive regulatory “sandboxes” that allow for iterative policy testing. By combining clear legal mandates with multi-stakeholder oversight, we can ensure that social media continues to serve the public good.
#
# ---
#
# # Explanatory Comments and Suggestions
#
# 1. **Strengthened Thesis (Section 1):**
#    – Moved thesis to end of introduction and made it more specific (balance of rights, transparency, innovation).
# 2. **Clearer Literature Review (Section 2):**
#    – Split into subheadings for digital governance, national approaches, and catalysts for reform.
#    – Added recent citations to illustrate evolving debates.
# 3. **Improved Argument Flow (Sections 3–4):**
#    – Organized pros and cons into parallel subsections (3.1/3.2 vs. 4.1/4.2) for symmetry and clearer comparison.
# 4. **Added Illustrations (Section 5):**
#    – Included a diagram (described in markdown) for the multi-stakeholder model.
#    – Provided a comparative table of regulation frameworks to visualize trade-offs.
# 5. **Enhanced Transitions:**
#    – Each section now begins with a brief topic sentence and ends with a transition statement.
# 6. **Terminology and Style:**
#    – Standardized terms (e.g., “algorithmic accountability,” “surveillance capitalism”).
#    – Varied sentence structure and reduced nominalizations for readability.
# 7. **Future Research (Conclusion):**
#    – Suggested specific directions (interoperable standards, regulatory sandboxes) to underscore academic rigor and forward momentum.
#
# Please let me know if you’d like further detail on any point or additional diagrams/equations to illustrate specific concepts.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">```markdown
# # Should Social Media Platforms Be Regulated by the Government?
#
# ## 1. Introduction
# The exponential rise of social media platforms over the past two decades has revolutionized communication, enabling unprecedented connectivity and democratization of information. At the same time, platforms such as Facebook, Twitter, and Instagram have given rise to serious ethical, social, and political challenges—most notably privacy infringements, the rapid spread of misinformation, and the manipulation of democratic processes.
#
# **Thesis (revised):**
# While government regulation of social media is necessary to safeguard democratic norms and individual rights, such regulation must be narrowly tailored—enhancing transparency, protecting privacy, and ensuring accountability—without stifling innovation or infringing on free expression.
#
# ## 2. Background and Literature Review
#
# ### 2.1 Digital Governance and Platform Power
# Scholars like Gillespie (2018) and van Dijck (2013) emphasize how major platforms operate under market logics that may conflict with public interests. As private entities, they set content-moderation rules, design proprietary algorithms, and monetize user data.
#
# ### 2.2 National Approaches to Regulation
# - **European Union (GDPR):** Establishes robust data-protection rights and penalties for non-compliance (MacCarthy, 2020).
# - **United States:** Relies largely on self-regulation, grounded in free-speech traditions (Klonick, 2018).
# - **Emerging Economies:** Face resource constraints and often adopt ad hoc measures, risking both under- and over-regulation (MacKinnon, 2012).
#
# ### 2.3 Recent Catalysts for Reform
# The Cambridge Analytica scandal (2018) and documented cases of electoral interference have intensified calls for more stringent oversight (Wardle & Derakhshan, 2017; Zuboff, 2019).
#
# ## 3. The Case for Government Regulation
#
# ### 3.1 Privacy and Surveillance Capitalism
# Platforms amass detailed profiles of users—often without explicit, informed consent—fueling “surveillance capitalism” (Zuboff, 2019). Regulation can:
# - Mandate clear, granular consent mechanisms
# - Limit data retention periods
# - Impose penalties for unauthorized secondary data use
#
# ### 3.2 Misinformation and Public Harm
# False or misleading content can spread exponentially, shaping public opinion and causing real-world harm (Wardle & Derakhshan, 2017). Government-mandated transparency in content-moderation policies and independent fact-checking bodies could mitigate these risks.
#
# ## 4. Counterarguments
#
# ### 4.1 Innovation and Free Expression
# Lessig (2006) warns that heavy-handed rules may deter startups and chill legitimate speech. Any regulatory regime must preserve:
# - Low barriers to entry for new platforms
# - Protections for political and artistic expression
#
# ### 4.2 Risks of Government Overreach
# Authoritarian regimes may exploit regulation to suppress dissent (Deibert, 2018). Furthermore, the cross-border nature of social media calls for international coordination—often impeded by divergent legal and cultural norms (Floridi, 2014).
#
# ## 5. Potential Regulatory Frameworks
#
# ### 5.1 Multi-Stakeholder Governance
# Collaborative models bring together governments, tech firms, civil society, and academia.
# ```markdown
# Figure 1: Multi-Stakeholder Governance Model
# - Government: Sets baseline rules and enforcement
# - Platforms: Implement and report on compliance
# - Civil society: Monitors impact and raises public concerns
# - Academia/Experts: Evaluate algorithms and advise on best practices
# ```
#
# ### 5.2 Algorithmic Accountability
# Mandating “algorithmic impact assessments” would require platforms to audit recommendation systems for bias and manipulation.
#
# | Framework                      | Scope                     | Advantages                         | Challenges                              |
# |--------------------------------|---------------------------|------------------------------------|-----------------------------------------|
# | EU Digital Services Act (DSA)  | Civil liability & rights  | Strong consumer protections        | Implementation across non-EU platforms  |
# | Algorithmic Impact Assessments | Algorithmic transparency  | Mitigates hidden biases            | Proprietary concerns & technical costs  |
#
# ## 6. Conclusion
# Government regulation of social media is both urgent and feasible—but only if it balances three core objectives: (1) protecting individual rights (privacy, expression), (2) safeguarding democratic processes (preventing misinformation and manipulation), and (3) fostering innovation (low entry barriers, algorithmic R&D). Future research should develop interoperable, international standards and explore adaptive regulatory “sandboxes” that allow for iterative policy testing. By combining clear legal mandates with multi-stakeholder oversight, we can ensure that social media continues to serve the public good.
# ```</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
